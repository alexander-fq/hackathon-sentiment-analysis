# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv(r'../../resources/dataset_sentimientos_robusto.csv')
df.head()
# Out:
#    id                                              texto sentimiento  \
# 0   1                                       Es aceptable      Neutro
# 1   2                      Es adecuado. Servicio regular      Neutro
# 2   3                          El servicio fue malísimo!    Negativo
# 3   4  Entrega rápida y producto impecable. Servicio ...    Positivo
# 4   5                         No lo recomiendo para nada    Negativo
#
#           categoria       fecha dia_semana hora_aproximada  es_fin_de_semana  \
# 0   Soporte Técnico  2024-12-09     Monday           Noche             False
# 1          Delivery  2025-08-03     Sunday           Tarde              True
# 2          Delivery  2024-02-04     Sunday           Noche              True
# 3  Aplicación Móvil  2025-11-15   Saturday          Mañana              True
# 4             Hotel  2024-09-26   Thursday           Noche             False
#
#    calificacion      canal  ... num_palabras  tiene_mayusculas_excesivas  \
# ...
